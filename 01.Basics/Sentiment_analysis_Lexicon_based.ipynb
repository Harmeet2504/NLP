# %% [markdown]
# # Sentiment Analysis (Lexicon based approach)
#
# Using TextBlob that works on top of nltk

# %%
import pandas as pd
from textblob import TextBlob

# %%
TextBlob("great").sentiment
# Out:
# Sentiment(polarity=0.8, subjectivity=0.75)

# %%
TextBlob("not great").sentiment
# Out:
# Sentiment(polarity=-0.4, subjectivity=0.75)

# %% [markdown]
# polarity*0.5

# %%
TextBlob("very great").sentiment
# Out:
# Sentiment(polarity=1.0, subjectivity=0.9750000000000001)

# %% [markdown]
# polarity* 1.3,
# subjectivity* 1.3

# %%
TextBlob("I am great").sentiment
# Out:
# Sentiment(polarity=0.8, subjectivity=0.75)

# %% [markdown]
# "I am" has no sentiments attached, hence gets back the same result
# So, this is a **Rule based** approach

# %% [markdown]
# ![Screen%20Shot%202020-07-15%20at%2011.49.38%20AM.png](attachment:Screen%20Shot%202020-07-15%20at%2011.49.38%20AM.png)
# ![Screen%20Shot%202020-07-15%20at%2011.49.15%20AM.png](attachment:Screen%20Shot%202020-07-15%20at%2011.49.15%20AM.png)
# ![Screen%20Shot%202020-07-17%20at%2010.10.54%20AM.png](attachment:Screen%20Shot%202020-07-17%20at%2010.10.54%20AM.png)
